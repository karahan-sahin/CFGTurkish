# %%
import pandas as pd

# %%
propbank = pd.read_csv("propbank_update.csv")

# %%
propbank.head()
# Out:
#               ID      VERB                                         DEFINITION  \
# 0  TUR10-0739570  takılmak  Karşı cins ile ilişki kurmayı veya arkadaş olm...
# 1  TUR10-0025740  aldanmak                                 Avunmak, oyalanmak
# 2  TUR10-0171430    çizmek               Kişiyle ilgiyi kesmek, bağı koparmak
# 3  TUR10-0069850  bağlamak  Birini söz veya yazı ile bağlamak; taahhüt etm...
# 4  TUR10-0594870   oturmak                            Biriyle beraber yaşamak
#
#                                      EXAMPLE                            ARG0  \
# 0                                        NaN  karşı cinsle arkadaş olan kişi
# 1  Küçük oğlan oyuncak bir arabayla aldandı.                     avunan kişi
# 2        Ben onu çizdim, artık görüşmüyorun.               bağı koparan kişi
# 3                                        NaN                   bağlayan kişi
# 4    O günden beri, enişte beyle oturuyorum.            beraber yaşayan kişi
#
# ...

# %%
args = ["NOM, ACC, DAT, ABL, INS, LOC, GEN","NOM, ACC, DAT, ABL, INS, LOC, GEN.1","NOM, ACC, DAT, ABL, INS, LOC, GEN.2","NOM, ACC, DAT, ABL, INS, LOC, GEN.3"]

# %%
propbank[propbank["VERB"]=="gitmek"][args[0]].apply(lambda x: x.capitalize()).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-542bcb9c8b93> in <module>
# ----> 1 propbank[propbank["VERB"]=="gitmek"][args].unique()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
for inst in enumerate(range(len(propbank))):
